# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.1.2 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: torchaudio>=2.1.2 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: lightning>=2.1.3 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.5.0.post0)
# Requirement already satisfied: hydra-core>=1.3.2 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: hydra-colorlog in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: nnAudio>=0.3.2 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.3.3)
# Requirement already satisfied: rich>=13.7.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (13.9.4)
# Requirement already satisfied: rootutils>=1.0.7 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (1.0.7)
# Requirement already satisfied: filelock in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from torch>=2.1.2->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from torch>=2.1.2->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: sympy==1.13.1 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from torch>=2.1.2->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: networkx in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from torch>=2.1.2->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from torch>=2.1.2->-r requirements.txt (line 2)) (3.1.5)
# Requirement already satisfied: fsspec in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from torch>=2.1.2->-r requirements.txt (line 2)) (2024.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.1.2->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from lightning>=2.1.3->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from lightning>=2.1.3->-r requirements.txt (line 6)) (0.11.9)
# Requirement already satisfied: packaging<25.0,>=20.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from lightning>=2.1.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from lightning>=2.1.3->-r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from lightning>=2.1.3->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: pytorch-lightning in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from lightning>=2.1.3->-r requirements.txt (line 6)) (2.5.0.post0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from hydra-core>=1.3.2->-r requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from hydra-core>=1.3.2->-r requirements.txt (line 9)) (4.9.3)
# Requirement already satisfied: colorlog in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from hydra-colorlog->-r requirements.txt (line 10)) (6.9.0)
# Requirement already satisfied: scipy>=1.2.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from nnAudio>=0.3.2->-r requirements.txt (line 13)) (1.15.1)
# Requirement already satisfied: numpy>=1.14.5 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from nnAudio>=0.3.2->-r requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from rich>=13.7.0->-r requirements.txt (line 16)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from rich>=13.7.0->-r requirements.txt (line 16)) (2.19.1)
# Requirement already satisfied: python-dotenv>=0.20.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from rootutils>=1.0.7->-r requirements.txt (line 17)) (1.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (3.11.11)
# Requirement already satisfied: setuptools in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.1.3->-r requirements.txt (line 6)) (75.1.0)
# Requirement already satisfied: mdurl~=0.1 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.0->-r requirements.txt (line 16)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from jinja2->torch>=2.1.2->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (1.18.3)
# Requirement already satisfied: idna>=2.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.3->-r requirements.txt (line 6)) (3.7)

# %%
# !pip install mir_eval
# Out:
# Requirement already satisfied: mir_eval in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (0.7)
# Requirement already satisfied: numpy>=1.7.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from mir_eval) (2.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from mir_eval) (1.15.1)
# Requirement already satisfied: future in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from mir_eval) (1.0.0)
# Requirement already satisfied: six in /home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages (from mir_eval) (1.17.0)

# %%
# %cd dataset

# !find Vocals -name "*.wav" | sort > my_dataset.csv
# !find PitchLabel  -name "*.csv" | sort > my_dataset_annot.csv

# %cd ..
# Out:
# [Errno 2] No such file or directory: 'dataset'
# /home/minho/pitch-match-music/pesto_training/pesto-full/pesto-full
# find: ‘Vocals’: No such file or directory
# find: ‘PitchLabel’: No such file or directory
# /home/minho/pitch-match-music/pesto_training/pesto-full

# %%
import torch

# PyTorch 버전
print("🔹 PyTorch 버전:", torch.__version__)

# CUDA 지원 여부
cuda_available = torch.cuda.is_available()
print("🔹 CUDA 지원 여부:", cuda_available)

# CUDA 버전 확인
if cuda_available:
    print("🔹 CUDA 버전:", torch.version.cuda)
    
    # cuDNN 버전 확인
    print("🔹 cuDNN 버전:", torch.backends.cudnn.version())

    # cuDNN 활성화 여부
    print("🔹 cuDNN 사용 가능 여부:", torch.backends.cudnn.enabled)

    # 사용 가능한 GPU 디바이스 개수
    print("🔹 사용 가능한 GPU 디바이스 수:", torch.cuda.device_count())

    # 현재 사용 중인 GPU 정보
    for i in range(torch.cuda.device_count()):
        print(f"🔹 GPU {i} 이름: {torch.cuda.get_device_name(i)}")
else:
    print("❌ CUDA가 활성화되지 않았습니다. CPU 모드로 실행됩니다.")
# Out:
# 🔹 PyTorch 버전: 2.5.0
# 🔹 CUDA 지원 여부: True
# 🔹 CUDA 버전: 12.4
# 🔹 cuDNN 버전: 90100
# 🔹 cuDNN 사용 가능 여부: True
# 🔹 사용 가능한 GPU 디바이스 수: 1
# 🔹 GPU 0 이름: NVIDIA GeForce RTX 4070 Ti SUPER

# %%
# !nvidia-smi
# Out:
# Wed Jan 29 22:12:26 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.216.03             Driver Version: 566.36       CUDA Version: 12.7     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...    On  | 00000000:01:00.0  On |                  N/A |
# |  0%   36C    P8              15W / 285W |   2521MiB / 16376MiB |     10%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !python src/train.py data=my_dataset logger=csv
# Out:
# [2025-01-29 22:12:50,863][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2025-01-29 22:12:50,865][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# CONFIG
# ├── data
# │   └── _target_: src.data.audio_datamodule.AudioDataModule
# │       audio_files: ./data/mir-1k.csv
# │       harmonics:
# │       - 1
# │       hop_duration: 20.0
# │       fmin: 27.5
# │       fmax: null
# │       bins_per_semitone: 3
# │       n_bins: 296
# │       center_bins: true
# │       batch_size: 256
# │       num_workers: 8
# │       pin_memory: true
# │       transforms:
# │       - _target_: src.data.transforms.ToLogMagnitude
# │       cache_dir: ./cache
# │       filter_unvoiced: false
# │       mmap_mode: null
# │       fold: null
# │       n_folds: 5
# │       annot_files: ./data/mir-1k_annot.csv
# │
# ├── model
# │   └── _target_: src.models.pesto.PESTO
# │       encoder:
# │         _target_: src.models.networks.resnet1d.Resnet1d
# │         n_chan_input: 1
# │         n_chan_layers:
# │         - 40
# │         - 30
# │         - 30
# │         - 10
# │         - 3
# │         n_prefilt_layers: 2
# │         prefilt_kernel_size: 15
# │         residual: true
# │         n_bins_in: 264
# │         output_dim: 384
# │       equiv_loss_fn:
# │         _target_: src.losses.equivariance.PowerSeries
# │         value: 1.019440644
# │         power_min: -383
# │         power_max: 1
# │         tau: 0.122462048
# │       inv_loss_fn:
# │         _target_: src.losses.entropy.CrossEntropyLoss
# │         symmetric: true
# │         detach_targets: true
# │       sce_loss_fn:
# │         _target_: src.losses.entropy.ShiftCrossEntropy
# │         pad_length: 16
# │         criterion:
# │           _target_: src.losses.entropy.CrossEntropyLoss
# │           symmetric: true
# │           detach_targets: true
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.0001
# │         weight_decay: 0
# │       scheduler:
# │         _target_: torch.optim.lr_scheduler.CosineAnnealingLR
# │         _partial_: true
# │         T_max: 50
# │       pitch_shift_kwargs:
# │         min_steps: -16
# │         max_steps: 16
# │       transforms:
# │       - _target_: src.data.transforms.BatchRandomNoise
# │         min_snr: 0.1
# │         max_snr: 2.0
# │         p: 0.7
# │       - _target_: src.data.transforms.BatchRandomGain
# │         min_gain: 0.5
# │         max_gain: 1.5
# │         p: 0.7
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: lightning.pytorch.callbacks.ModelCheckpoint
# │         dirpath: null
# │         filename: null
# │         monitor: null
# │         verbose: false
# │         save_last: null
# │         save_top_k: 1
# │         mode: min
# │         auto_insert_metric_name: true
# │         save_weights_only: true
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       lr_monitor:
# │         _target_: lightning.pytorch.callbacks.LearningRateMonitor
# │       model_summary:
# │         _target_: lightning.pytorch.callbacks.RichModelSummary
# │         max_depth: 1
# │       progress_bar:
# │         _target_: lightning.pytorch.callbacks.RichProgressBar
# │       loss_weighting:
# │         _target_: src.callbacks.loss_weighting.GradientsLossWeighting
# │         weights:
# │           invariance: 0.0
# │           shift_entropy: 1.0
# │           equivariance: 0.0
# │         ema_rate: 0.999
# │       mir_eval:
# │         _target_: src.callbacks.mir_eval.MIREvalCallback
# │         cdf_resolution: 10
# │       pitch_histogram:
# │         _target_: src.callbacks.pitch_histogram.PitchHistogramCallback
# │
# ├── logger
# │   └── csv:
# │         _target_: lightning.pytorch.loggers.csv_logs.CSVLogger
# │         save_dir: /home/minho/pitch-match-music/pesto_training/pesto-full/logs
# │         name: csv/
# │         prefix: ''
# │
# ├── trainer
# │   └── _target_: lightning.pytorch.trainer.Trainer
# │       default_root_dir: /home/minho/pitch-match-music/pesto_training/pesto-ful
# │       log_every_n_steps: 200
# │       max_epochs: 50
# │       accelerator: gpu
# │       devices: 1
# │
# ├── paths
# │   └── root_dir: .
# │       data_dir: ./data
# │       log_dir: ./logs/
# │       output_dir: /home/minho/pitch-match-music/pesto_training/pesto-full/logs
# │       ckpt_dir: /home/minho/pitch-match-music/pesto_training/pesto-full/logs/t
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: true
# │       print_config: true
# │       save_config: true
# │
# ├── task_name
# │   └── train
# ├── tags
# │   └── ['dev']
# ├── train
# │   └── True
# ├── test
# │   └── False
# ├── ckpt_path
# │   └── None
# └── seed
#     └── 0
# [2025-01-29 22:12:50,897][src.utils.utils][INFO] - Saving config in /home/minho/pitch-match-music/pesto_training/pesto-full/logs/train/runs/2025-01-29_22-12-50/config.yaml! <cfg.extras.save_config=True>
# [2025-01-29 22:12:50,906][__main__][INFO] - Instantiating datamodule <src.data.audio_datamodule.AudioDataModule>
# [2025-01-29 22:12:50,941][__main__][INFO] - Instantiating model <src.models.pesto.PESTO>
# [2025-01-29 22:12:50,950][__main__][INFO] - Instantiating callbacks...
# [2025-01-29 22:12:50,950][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2025-01-29 22:12:50,952][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.LearningRateMonitor>
# [2025-01-29 22:12:50,952][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichModelSummary>
# [2025-01-29 22:12:50,952][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichProgressBar>
# [2025-01-29 22:12:50,952][src.utils.instantiators][INFO] - Instantiating callback <src.callbacks.loss_weighting.GradientsLossWeighting>
# [2025-01-29 22:12:50,953][src.utils.instantiators][INFO] - Instantiating callback <src.callbacks.mir_eval.MIREvalCallback>
# [2025-01-29 22:12:50,964][src.utils.instantiators][INFO] - Instantiating callback <src.callbacks.pitch_histogram.PitchHistogramCallback>
# [2025-01-29 22:12:50,965][__main__][INFO] - Instantiating loggers...
# [2025-01-29 22:12:50,965][src.utils.instantiators][INFO] - Instantiating logger <lightning.pytorch.loggers.csv_logs.CSVLogger>
# [2025-01-29 22:12:50,966][__main__][INFO] - Instantiating trainer <lightning.pytorch.trainer.Trainer>
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [2025-01-29 22:12:51,017][__main__][INFO] - Logging hyperparameters!
# [2025-01-29 22:12:51,019][__main__][INFO] - Starting training!
# [2025-01-29 22:12:51,090][src.utils.utils][ERROR] -
# Traceback (most recent call last):
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/utils/utils.py", line 74, in wrap
#     metric_dict, object_dict = task_func(cfg=cfg)
#                                ^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/train.py", line 94, in train
#     trainer.fit(model=model, datamodule=datamodule, ckpt_path=cfg.get("ckpt_path"))
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 539, in fit
#     call._call_and_handle_interrupt(
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 47, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 575, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 942, in _run
#     self._data_connector.prepare_data()
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py", line 94, in prepare_data
#     call._call_lightning_datamodule_hook(trainer, "prepare_data")
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 193, in _call_lightning_datamodule_hook
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/data/audio_datamodule.py", line 133, in prepare_data
#     self.train_dataset = self.load_data(self.audio_files, self.annot_files)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/data/audio_datamodule.py", line 186, in load_data
#     inputs, annotations = self.precompute_hcqt(audio_files, annot_files)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/data/audio_datamodule.py", line 209, in precompute_hcqt
#     with audio_path.open('r') as f:
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/pathlib.py", line 1044, in open
#     return io.open(self, mode, buffering, encoding, errors, newline)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'data/mir-1k.csv'
# [2025-01-29 22:12:51,091][src.utils.utils][INFO] - Output dir: /home/minho/pitch-match-music/pesto_training/pesto-full/logs/train/runs/2025-01-29_22-12-50
# Error executing job with overrides: ['data=mir-1k', 'logger=csv']
# Traceback (most recent call last):
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/train.py", line 127, in main
#     metric_dict, _ = train(cfg)
#                      ^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/utils/utils.py", line 84, in wrap
#     raise ex
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/utils/utils.py", line 74, in wrap
#     metric_dict, object_dict = task_func(cfg=cfg)
#                                ^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/train.py", line 94, in train
#     trainer.fit(model=model, datamodule=datamodule, ckpt_path=cfg.get("ckpt_path"))
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 539, in fit
#     call._call_and_handle_interrupt(
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 47, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 575, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 942, in _run
#     self._data_connector.prepare_data()
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py", line 94, in prepare_data
#     call._call_lightning_datamodule_hook(trainer, "prepare_data")
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 193, in _call_lightning_datamodule_hook
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/data/audio_datamodule.py", line 133, in prepare_data
#     self.train_dataset = self.load_data(self.audio_files, self.annot_files)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/data/audio_datamodule.py", line 186, in load_data
#     inputs, annotations = self.precompute_hcqt(audio_files, annot_files)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/pitch-match-music/pesto_training/pesto-full/src/data/audio_datamodule.py", line 209, in precompute_hcqt
#     with audio_path.open('r') as f:
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/home/minho/miniconda3/envs/pitch_match/lib/python3.11/pathlib.py", line 1044, in open
#     return io.open(self, mode, buffering, encoding, errors, newline)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'data/mir-1k.csv'
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
